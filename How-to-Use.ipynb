# %% [markdown]
# # Hello Quantum for Jupyter notebook
#
# [Hello Quantum](https://helloquantum.mybluemix.net/) is a project based on the idea of visualizing two qubit states and gates, and making them accessible to a non-specialist audience.
#
# In this folder you'll find some of the ideas of 'Hello Quantum' implemented for Jupyter notebooks. It is intended that these will provide a resource for presentations by IBMers, self-study by potention Qiskit users, and a replacement for the [command line Hello Quantum](https://www.pythonanywhere.com/gists/a5d885816f7dc042a78df11ce6cf9652/main.py/ipython3/).
#
# To use it, import `engine` and use matplotlib magic.

# %%
# %matplotlib notebook
import engine

# %% [markdown]
# Then you can set up and display the visualization.

# %%
grid = engine.pauli_grid()
grid.update_grid()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# This has attributes and methods which create and run quantum circuits with Qiskit.

# %%
for gate in [['x','1'],['h','0'],['z','0'],['h','1'],['z','1']]:
    command = 'grid.qc.'+gate[0]+'(grid.qr['+gate[1]+'])'
    eval(command)
    grid.update_grid()

# %% [markdown]
# There is also an alternative visualization, which can be used to better represent non-Clifford gates.

# %%
grid = engine.pauli_grid(mode='line')
grid.update_grid()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# The `run_game` function, can also be used to implement custom 'Hello Quantum' games within a notebook. One example can be found below, but it is better to look at the other notebooks in this folder.

# %%
initialize = [['x', '0']]
success_condition = {'IZ': -1.0}
allowed_gates = {'0': {'h':0}, '1': {'h':0}, 'both': {'cz': 0}}
vi = [[], True, True]
qubit_names = {'0':'qubit 0', '1':'qubit 1'}
engine.run_game(initialize, success_condition, allowed_gates, vi, qubit_names)
# Out:
# <div id='7df61ca1-bcf6-4f30-b8dc-687ce654c40f'></div>
# qubit  qubit_name 0
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-57c9e944ed79>", line 6, in <module>
#     engine.run_game(initialize, success_condition, allowed_gates, vi, qubit_names)
#
#   File "/Users/jwo/Box Sync/TutorialPlanning/community-qiskit-tutorials/game-tutorial/Hello-Quantum-Qiskit/engine.py", line 82, in __init__
#     eval( get_command(gate[0],gate[1])[0] )
#
#   File "<string>", line 1
#     grid.qc.x(grid.qr[])
#                       ^
# SyntaxError: invalid syntax
